# %% [markdown]
# # Tahap 2 - Data Preprocessing
#
# Notebook ini memakai mapping kolom aktual hasil Tahap 0. Jalankan setelah `docs/dataset_analysis.md` selesai dibuat.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()
if not (PROJECT_ROOT / "src").exists() and (PROJECT_ROOT.parent / "src").exists():
    PROJECT_ROOT = PROJECT_ROOT.parent

sys.path.insert(0, str(PROJECT_ROOT))
PROJECT_ROOT

# %%
from src.data_loader import preprocess_alumni_dataset, summarize_processed_dataset

dataset = preprocess_alumni_dataset(PROJECT_ROOT / "data" / "raw")
summarize_processed_dataset(dataset)

# %%
dataset.alumni.head()

# %%
dataset.universities.head()

# %%
from src.data_loader import save_processed_dataset

saved_paths = save_processed_dataset(dataset, PROJECT_ROOT / "data" / "processed")
saved_paths
