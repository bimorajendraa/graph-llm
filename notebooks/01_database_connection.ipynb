# %% [markdown]
# # Tahap 1 - Database Connection
#
# Jalankan Neo4j terlebih dahulu dengan `docker compose up -d`, lalu verifikasi koneksi dari notebook ini.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()
if not (PROJECT_ROOT / "src").exists() and (PROJECT_ROOT.parent / "src").exists():
    PROJECT_ROOT = PROJECT_ROOT.parent
sys.path.insert(0, str(PROJECT_ROOT))

# %%
from src.database import Neo4jConnection

db = Neo4jConnection()
db.verify()
db.run_query("RETURN 'Neo4j connected' AS message")

# %%
db.close()
