# %% [markdown]
# # Tahap 4 - LLM Graph Builder
#
# Dataset utama tidak memiliki kolom biodata naratif. Untuk tahap ini, tambahkan file `.txt` biodata alumni ke `data/biographies`, lalu gunakan LLM untuk ekstraksi entitas.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()
if not (PROJECT_ROOT / "src").exists() and (PROJECT_ROOT.parent / "src").exists():
    PROJECT_ROOT = PROJECT_ROOT.parent
sys.path.insert(0, str(PROJECT_ROOT))

biography_dir = PROJECT_ROOT / "data" / "biographies"
biography_files = list(biography_dir.glob("*.txt"))
biography_files

# %%
from src.graph_builder import extract_graph_from_biography

if biography_files:
    text = biography_files[0].read_text(encoding="utf-8")
    extract_graph_from_biography(text)
else:
    "Tambahkan file .txt ke data/biographies terlebih dahulu."
