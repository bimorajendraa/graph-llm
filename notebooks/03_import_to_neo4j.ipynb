# %% [markdown]
# # Tahap 3 - Import to Neo4j
#
# Notebook ini mengimpor CSV hasil preprocessing ke Neo4j.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()
if not (PROJECT_ROOT / "src").exists() and (PROJECT_ROOT.parent / "src").exists():
    PROJECT_ROOT = PROJECT_ROOT.parent
sys.path.insert(0, str(PROJECT_ROOT))

# %%
from src.graph_builder import import_graph

import_graph(PROJECT_ROOT / "data" / "processed")
