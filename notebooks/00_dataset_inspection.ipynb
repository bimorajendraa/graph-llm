# %% [markdown]
# # Tahap 0 - Dataset Inspection
#
# Notebook ini membaca seluruh CSV pada `data/raw` tanpa mengasumsikan nama kolom. Jalankan notebook ini sebelum membuat koneksi Neo4j atau pipeline import.

# %% [markdown]
# ## 1. Ambil Dataset
#
# Jalankan perintah berikut dari terminal PowerShell di root proyek:
#
# ```powershell
# git clone https://github.com/burhansa25/graph.git data/source_repo
# Get-ChildItem .\data\source_repo -Recurse -Filter *.csv | Copy-Item -Destination .\data\raw
# ```

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()
if not (PROJECT_ROOT / "src").exists() and (PROJECT_ROOT.parent / "src").exists():
    PROJECT_ROOT = PROJECT_ROOT.parent

sys.path.insert(0, str(PROJECT_ROOT))
PROJECT_ROOT

# %%
from src.dataset_inspector import scan_dataset_files

csv_files = scan_dataset_files(PROJECT_ROOT / "data" / "raw")
csv_files

# %%
from src.dataset_inspector import inspect_dataset

reports = inspect_dataset(PROJECT_ROOT / "data" / "raw", sample_size=5)

for report in reports:
    print(f"File: {report.relative_path}")
    print(f"Baris: {report.row_count}")
    print(f"Kolom: {report.column_count}")
    print(", ".join(report.columns))
    print("-" * 80)

# %%
from src.dataset_inspector import generate_dataset_report, save_dataset_report

report = generate_dataset_report(PROJECT_ROOT / "data" / "raw", sample_size=5)
output_path = save_dataset_report(report, PROJECT_ROOT / "docs" / "dataset_analysis.md")
output_path

# %%
print(report[:4000])
