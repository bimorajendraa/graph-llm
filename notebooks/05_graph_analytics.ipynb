# %% [markdown]
# # Tahap 5 - Graph Analytics

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()
if not (PROJECT_ROOT / "src").exists() and (PROJECT_ROOT.parent / "src").exists():
    PROJECT_ROOT = PROJECT_ROOT.parent
sys.path.insert(0, str(PROJECT_ROOT))

# %%
from src.database import Neo4jConnection
from src.graph_analytics import GraphAnalytics

db = Neo4jConnection()
analytics = GraphAnalytics(db)
analytics.university_alumni_counts(limit=10)

# %%
analytics.occupation_counts(limit=10)

# %%
analytics.create_gds_projection()
